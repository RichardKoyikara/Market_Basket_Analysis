# %% [markdown]
# # Capstone Project (Market Basket Analysis)

# %% [markdown]
# # Loading Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import os
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # Importing Cleaned data

# %%
My_data = pd.read_csv('New_Transcations_Records.csv')
My_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                    InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010-12-01 08:26:00.0000000       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00.0000000       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00.0000000       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00.0000000       3.39       17850  United Kingdom
# 4  2010-12-01 08:26:00.0000000       3.39       17850  United Kingdom
#
#   Invoice_Date      Invoice_Time
# 0   2010-12-01  08:26:00.0000000
# 1   2010-12-01  08:26:00.0000000
# 2   2010-12-01  08:26:00.0000000
# 3   2010-12-01  08:26:00.0000000
# 4   2010-12-01  08:26:00.0000000

# %%
# Size of the Data
My_data.shape
# Out:
# (405633, 10)

# %%
#Data Preprocessing
# Checking for Null Values
My_data.isnull().sum()
# Out:
# InvoiceNo       0
# StockCode       0
# Description     0
# Quantity        0
# InvoiceDate     0
# UnitPrice       0
# CustomerID      0
# Country         0
# Invoice_Date    0
# Invoice_Time    0
# dtype: int64

# %%
My_data.dtypes
# Out:
# InvoiceNo        object
# StockCode        object
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# Invoice_Date     object
# Invoice_Time     object
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis (EDA) On the Dataset.

# %% [markdown]
# ### Number of Records as per the Country

# %%
My_data['Country'].value_counts()
# Out:
# United Kingdom          361792
# Germany                   9112
# France                    8180
# EIRE                      7485
# Spain                     2471
# Netherlands               2332
# Belgium                   1971
# Switzerland               1844
# Portugal                  1450
# Australia                 1257
# Norway                    1066
# Italy                      785
# Channel Islands            758
# Finland                    654
# Cyprus                     621
# Sweden                     438
# Austria                    387
# Denmark                    375
# Japan                      358
# Poland                     336
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     150
# Greece                     142
# Malta                      123
# United Arab Emirates        67
# European Community          58
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              28
# Bahrain                     17
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
# The Total Number of Countries The Company is working in

"The Number of Countries are :" + str(My_data['Country'].nunique())
# Out:
# 'The Number of Countries are :37'

# %% [markdown]
# ### Analyze the sales performance of the Company

# %%
Total_Amount = My_data['Quantity'] * My_data['UnitPrice']
My_data.insert(loc=7, column='TotalAmount', value=Total_Amount)

# %%
My_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                    InvoiceDate  UnitPrice  CustomerID  TotalAmount  \
# 0  2010-12-01 08:26:00.0000000       2.55       17850        15.30
# 1  2010-12-01 08:26:00.0000000       3.39       17850        20.34
# 2  2010-12-01 08:26:00.0000000       2.75       17850        22.00
# 3  2010-12-01 08:26:00.0000000       3.39       17850        20.34
# 4  2010-12-01 08:26:00.0000000       3.39       17850        20.34
#
#           Country Invoice_Date      Invoice_Time
# 0  United Kingdom   2010-12-01  08:26:00.0000000
# 1  United Kingdom   2010-12-01  08:26:00.0000000
# 2  United Kingdom   2010-12-01  08:26:00.0000000
# 3  United Kingdom   2010-12-01  08:26:00.0000000
# 4  United Kingdom   2010-12-01  08:26:00.0000000

# %% [markdown]
# ### Total Revenue of the Company according to the Countries

# %%
#  Grouping Countries by TotalAmount Of The Sales

country_price = My_data.groupby('Country')['TotalAmount'].sum().sort_values(ascending = False)
country_price
# Out:
# Country
# United Kingdom          6768627.364
# Netherlands              283167.540
# EIRE                     250285.220
# Germany                  200877.210
# France                   181647.840
# Australia                136990.000
# Switzerland               51859.400
# Spain                     48922.580
# Belgium                   36662.960
# Japan                     35340.620
# Sweden                    35206.910
# Norway                    32292.960
# Portugal                  26551.810
# Channel Islands           20086.290
# Finland                   18854.740
# Denmark                   18042.140
# Italy                     15245.510
# Cyprus                    12931.290
# Singapore                  9120.390
# Austria                    8698.320
# Israel                     6994.250
# Poland                     6853.140
# Greece                     4425.520
# Iceland                    4310.000
# Canada                     3115.440
# Unspecified                2667.070
# Malta                      1980.470
# United Arab Emirates       1864.780
# USA                        1730.920
# Lebanon                    1693.880
# Lithuania                  1661.060
# European Community         1150.750
# Brazil                     1143.600
# RSA                        1002.310
# Czech Republic              671.720
# Bahrain                     548.400
# Saudi Arabia                131.170
# Name: TotalAmount, dtype: float64

# %% [markdown]
# ### Top 5 Countries which the companies have highest sales

# %%
# Top 5 Countries which the companies have highest sales
country_price[:5].plot(kind = 'bar',color = 'darkgreen')
plt.pyplot.ylabel('TotalAmount')
# Out:
# Text(0, 0.5, 'TotalAmount')

# %% [markdown]
#  ### 5 Countries which the companies have lowest sales

# %%
 # 5 Countries which the companies have lowest sales
country_price[33:].plot(kind = 'bar', color='darkred')
plt.pyplot.ylabel('TotalAmount')
# Out:
# Text(0, 0.5, 'TotalAmount')

# %% [markdown]
# ### Why these Countries have low Sales ?

# %% [markdown]
# ### Countries with less number of customers

# %%
# Countries with less number of customers

cus_id = pd.DataFrame(My_data.groupby('Country')['CustomerID'].count().sort_values(ascending = False))
cus_id[-5:].plot(kind = 'bar',title = 'Least Customers for Country', color='darkred')
# Out:
# <AxesSubplot:title={'center':'Least Customers for Country'}, xlabel='Country'>

# %%
# Adding Year feature to the Dataset
My_data['InvoiceDate'] = pd.to_datetime(My_data['InvoiceDate'])
timest = My_data['InvoiceDate'].dt.year
My_data['Year'] = timest
My_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID  TotalAmount         Country  \
# 0 2010-12-01 08:26:00       2.55       17850        15.30  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850        20.34  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850        22.00  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850        20.34  United Kingdom
# 4 2010-12-01 08:26:00       3.39       17850        20.34  United Kingdom
#
#   Invoice_Date      Invoice_Time  Year
# 0   2010-12-01  08:26:00.0000000  2010
# 1   2010-12-01  08:26:00.0000000  2010
# 2   2010-12-01  08:26:00.0000000  2010
# 3   2010-12-01  08:26:00.0000000  2010
# 4   2010-12-01  08:26:00.0000000  2010

# %%
# Total Sales According to the Years
My_data.groupby('Year')['TotalAmount'].sum().plot(kind = 'bar', color='darkblue')
plt.pyplot.ylabel('TotalAmount')
# Out:
# Text(0, 0.5, 'TotalAmount')

# %% [markdown]
# ### Why the sales are low in Year 2010

# %%
# Checking the Sales of the products for different months

My_data['Month'] = My_data['InvoiceDate'].dt.month
My_data['Month_name'] = My_data['InvoiceDate'].dt.month_name()
My_data.groupby(['Year','Month'])['TotalAmount'].sum().plot(kind = 'bar', title = 'Sales Month Wise',color = 'blue')
# Out:
# <AxesSubplot:title={'center':'Sales Month Wise'}, xlabel='Year,Month'>

# %% [markdown]
# ### Total Sales of Each Product in the Transcation Dataset

# %%
total_sales = My_data.groupby(['StockCode','Description'])['Quantity','TotalAmount'].sum().sort_values(by = 'Quantity',ascending = False)
total_sales
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12204\2008709600.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   total_sales = My_data.groupby(['StockCode','Description'])['Quantity','TotalAmount'].sum().sort_values(by = 'Quantity',ascending = False)
#                                                Quantity  TotalAmount
# StockCode Description
# 84077     WORLD WAR 2 GLIDERS ASSTD DESIGNS       53215     13332.33
# 85099B    JUMBO BAG RED RETROSPOT                 45066     83236.76
# 84879     ASSORTED COLOUR BIRD ORNAMENT           35314     56499.22
# 85123A    WHITE HANGING HEART T-LIGHT HOLDER      34147     93823.85
# 21212     PACK OF 72 RETROSPOT CAKE CASES         33409     16247.95
# ...                                                 ...          ...
# 21144     PINK POODLE HANGING DECORATION            -12        -4.56
# CRUK      CRUK Commission                           -16     -7933.43
# 21645     ASSORTED TUTTI FRUTTI ROUND BOX           -24       -39.60
# D         Discount                                -1194     -5696.22
# 84347     ROTATING SILVER ANGELS T-LIGHT HLDR     -1460     17293.87
#
# [3912 rows x 2 columns]

# %% [markdown]
# # Market Basket Analysis

# %%
# Display the data
My_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 405628    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 405629    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 405630    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 405631    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 405632    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice  CustomerID  TotalAmount  \
# 0      2010-12-01 08:26:00       2.55       17850        15.30
# 1      2010-12-01 08:26:00       3.39       17850        20.34
# 2      2010-12-01 08:26:00       2.75       17850        22.00
# 3      2010-12-01 08:26:00       3.39       17850        20.34
# 4      2010-12-01 08:26:00       3.39       17850        20.34
# ...                    ...        ...         ...          ...
# 405628 2011-12-09 12:50:00       0.85       12680        10.20
# 405629 2011-12-09 12:50:00       2.10       12680        12.60
# 405630 2011-12-09 12:50:00       4.15       12680        16.60
# 405631 2011-12-09 12:50:00       4.15       12680        16.60
# 405632 2011-12-09 12:50:00       4.95       12680        14.85
#
#                Country Invoice_Date      Invoice_Time  Year  Month Month_name
# 0       United Kingdom   2010-12-01  08:26:00.0000000  2010     12   December
# 1       United Kingdom   2010-12-01  08:26:00.0000000  2010     12   December
# 2       United Kingdom   2010-12-01  08:26:00.0000000  2010     12   December
# 3       United Kingdom   2010-12-01  08:26:00.0000000  2010     12   December
# 4       United Kingdom   2010-12-01  08:26:00.0000000  2010     12   December
# ...                ...          ...               ...   ...    ...        ...
# 405628          France   2011-12-09  12:50:00.0000000  2011     12   December
# 405629          France   2011-12-09  12:50:00.0000000  2011     12   December
# 405630          France   2011-12-09  12:50:00.0000000  2011     12   December
# 405631          France   2011-12-09  12:50:00.0000000  2011     12   December
# 405632          France   2011-12-09  12:50:00.0000000  2011     12   December
#
# [405633 rows x 14 columns]

# %% [markdown]
# ### Making a Transcation Basket

# %%
My_basket = (My_data.groupby(['InvoiceNo','Description'])['Quantity']
             .sum().unstack().reset_index().fillna(0)
             .set_index('InvoiceNo'))

# %% [markdown]
# ### Veiwing The Transcation Basket

# %%
My_basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
# ...                             ...                         ...
# C581484                         0.0                         0.0
# C581490                         0.0                         0.0
# C581499                         0.0                         0.0
# C581568                         0.0                         0.0
# C581569                         0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
# ...                                ...                        ...
# C581484                            0.0                        0.0
# C581490                            0.0                        0.0
# C581499                            0.0                        0.0
# C581568                            0.0                        0.0
# C581569                            0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
# ...                                   ...                               ...
# C581484                               0.0                               0.0
# C581490                               0.0                               0.0
# C581499                               0.0                               0.0
# C581568                               0.0                               0.0
# C581569                               0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
# ...                                      ...                            ...
# C581484                                  0.0                            0.0
# C581490                                  0.0                            0.0
# C581499                                  0.0                            0.0
# C581568                                  0.0                            0.0
# C581569                                  0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536365                                       0.0                          0.0
# 536366                                       0.0                          0.0
# 536367                                       0.0                          0.0
# 536368                                       0.0                          0.0
# 536369                                       0.0                          0.0
# ...                                          ...                          ...
# C581484                                      0.0                          0.0
# C581490                                      0.0                          0.0
# C581499                                      0.0                          0.0
# C581568                                      0.0                          0.0
# C581569                                      0.0                          0.0
#
# Description  ...  ZINC STAR T-LIGHT HOLDER  ZINC SWEETHEART SOAP DISH  \
# InvoiceNo    ...
# 536365       ...                       0.0                        0.0
# 536366       ...                       0.0                        0.0
# 536367       ...                       0.0                        0.0
# 536368       ...                       0.0                        0.0
# 536369       ...                       0.0                        0.0
# ...          ...                       ...                        ...
# C581484      ...                       0.0                        0.0
# C581490      ...                       0.0                        0.0
# C581499      ...                       0.0                        0.0
# C581568      ...                       0.0                        0.0
# C581569      ...                       0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                    0.0                             0.0
# 536366                                    0.0                             0.0
# 536367                                    0.0                             0.0
# 536368                                    0.0                             0.0
# 536369                                    0.0                             0.0
# ...                                       ...                             ...
# C581484                                   0.0                             0.0
# C581490                                   0.0                             0.0
# C581499                                   0.0                             0.0
# C581568                                   0.0                             0.0
# C581569                                   0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                   0.0                              0.0
# 536366                                   0.0                              0.0
# 536367                                   0.0                              0.0
# 536368                                   0.0                              0.0
# 536369                                   0.0                              0.0
# ...                                      ...                              ...
# C581484                                  0.0                              0.0
# C581490                                  0.0                            -11.0
# C581499                                  0.0                              0.0
# C581568                                  0.0                              0.0
# C581569                                  0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF  ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                 0.0                               0.0
# 536366                                 0.0                               0.0
# 536367                                 0.0                               0.0
# 536368                                 0.0                               0.0
# 536369                                 0.0                               0.0
# ...                                    ...                               ...
# C581484                                0.0                               0.0
# C581490                                0.0                               0.0
# C581499                                0.0                               0.0
# C581568                                0.0                               0.0
# C581569                                0.0                               0.0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                               0.0                               0.0
# 536366                               0.0                               0.0
# 536367                               0.0                               0.0
# 536368                               0.0                               0.0
# 536369                               0.0                               0.0
# ...                                  ...                               ...
# C581484                              0.0                               0.0
# C581490                              0.0                               0.0
# C581499                              0.0                               0.0
# C581568                              0.0                               0.0
# C581569                              0.0                               0.0
#
# [22072 rows x 3884 columns]

# %% [markdown]
# ### Converting all positive Values to 1 and everything else to 0

# %%
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
My_basket_sets = My_basket.applymap(my_encode_units)
My_basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                            0                           0
# 536366                            0                           0
# 536367                            0                           0
# 536368                            0                           0
# 536369                            0                           0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                  0                                 0
# 536366                                  0                                 0
# 536367                                  0                                 0
# 536368                                  0                                 0
# 536369                                  0                                 0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                     0                              0
# 536366                                     0                              0
# 536367                                     0                              0
# 536368                                     0                              0
# 536369                                     0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536365                                         0                            0
# 536366                                         0                            0
# 536367                                         0                            0
# 536368                                         0                            0
# 536369                                         0                            0
#
# Description  ...  ZINC STAR T-LIGHT HOLDER  ZINC SWEETHEART SOAP DISH  \
# InvoiceNo    ...
# 536365       ...                         0                          0
# 536366       ...                         0                          0
# 536367       ...                         0                          0
# 536368       ...                         0                          0
# 536369       ...                         0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536369                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536369                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF  ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                   0                                 0
# 536366                                   0                                 0
# 536367                                   0                                 0
# 536368                                   0                                 0
# 536369                                   0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536369                                 0                                 0
#
# [5 rows x 3884 columns]

# %% [markdown]
# ## Training Model

# %%
# Generating Frequent Itemsets

My_frequent_itemsets = apriori(My_basket_sets, min_support=0.02, use_colnames=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# Generating Rules

My_rules = association_rules(My_frequent_itemsets, metric="lift", min_threshold=1)

# %%
# Viewing Top 100 Rules

My_rules.head(10)
# Out:
#                            antecedents                          consequents  \
# 0         (ALARM CLOCK BAKELIKE GREEN)           (ALARM CLOCK BAKELIKE RED)
# 1           (ALARM CLOCK BAKELIKE RED)         (ALARM CLOCK BAKELIKE GREEN)
# 2  (GARDENERS KNEELING PAD CUP OF TEA)   (GARDENERS KNEELING PAD KEEP CALM)
# 3   (GARDENERS KNEELING PAD KEEP CALM)  (GARDENERS KNEELING PAD CUP OF TEA)
# 4     (PINK REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 5    (GREEN REGENCY TEACUP AND SAUCER)     (PINK REGENCY TEACUP AND SAUCER)
# 6    (ROSES REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 7    (GREEN REGENCY TEACUP AND SAUCER)    (ROSES REGENCY TEACUP AND SAUCER)
# 8            (JUMBO BAG PINK POLKADOT)            (JUMBO BAG RED RETROSPOT)
# 9            (JUMBO BAG RED RETROSPOT)            (JUMBO BAG PINK POLKADOT)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.035747            0.039734  0.024012    0.671736  16.906004
# 1            0.039734            0.035747  0.024012    0.604333  16.906004
# 2            0.028769            0.034252  0.020977    0.729134  21.287622
# 3            0.034252            0.028769  0.020977    0.612434  21.287622
# 4            0.025190            0.031307  0.020841    0.827338  26.426928
# 5            0.031307            0.025190  0.020841    0.665702  26.426928
# 6            0.035475            0.031307  0.024511    0.690932  22.069838
# 7            0.031307            0.035475  0.024511    0.782923  22.069838
# 8            0.039462            0.072490  0.024737    0.626866   8.647612
# 9            0.072490            0.039462  0.024737    0.341250   8.647612
#
#    leverage  conviction  zhangs_metric
# 0  0.022592    2.925290       0.975728
# 1  0.022592    2.437032       0.979780
# 2  0.019991    3.565409       0.981255
# 3  0.019991    2.505974       0.986825
# 4  0.020052    5.610349       0.987023
# 5  0.020052    2.915989       0.993255
# 6  0.023400    3.134243       0.989802
# 7  0.023400    4.443246       0.985543
# 8  0.021877    2.485727       0.920693
# 9  0.021877    1.458123       0.953479

# %% [markdown]
# ###   Frequencies of  the Products

# %%
My_basket_sets['ALARM CLOCK BAKELIKE RED'].sum()
# Out:
# 877

# %%
My_basket_sets['ALARM CLOCK BAKELIKE GREEN'].sum()
# Out:
# 789

# %%
My_basket_sets['JUMBO BAG RED RETROSPOT'].sum()
# Out:
# 1600

# %%
My_basket_sets['JUMBO BAG PINK POLKADOT'].sum()
# Out:
# 871

# %% [markdown]
# ### Filtering the Association Rules between the Products

# %%
My_rules[(My_rules['lift'] >= 5) & (My_rules['confidence'] >= 0.4)]
# Out:
#                             antecedents                           consequents  \
# 0          (ALARM CLOCK BAKELIKE GREEN)            (ALARM CLOCK BAKELIKE RED)
# 1            (ALARM CLOCK BAKELIKE RED)          (ALARM CLOCK BAKELIKE GREEN)
# 2   (GARDENERS KNEELING PAD CUP OF TEA)    (GARDENERS KNEELING PAD KEEP CALM)
# 3    (GARDENERS KNEELING PAD KEEP CALM)   (GARDENERS KNEELING PAD CUP OF TEA)
# 4      (PINK REGENCY TEACUP AND SAUCER)     (GREEN REGENCY TEACUP AND SAUCER)
# 5     (GREEN REGENCY TEACUP AND SAUCER)      (PINK REGENCY TEACUP AND SAUCER)
# 6     (ROSES REGENCY TEACUP AND SAUCER)     (GREEN REGENCY TEACUP AND SAUCER)
# 7     (GREEN REGENCY TEACUP AND SAUCER)     (ROSES REGENCY TEACUP AND SAUCER)
# 8             (JUMBO BAG PINK POLKADOT)             (JUMBO BAG RED RETROSPOT)
# 10            (LUNCH BAG  BLACK SKULL.)             (LUNCH BAG PINK POLKADOT)
# 11            (LUNCH BAG PINK POLKADOT)             (LUNCH BAG  BLACK SKULL.)
# 12            (LUNCH BAG  BLACK SKULL.)             (LUNCH BAG RED RETROSPOT)
# 13            (LUNCH BAG RED RETROSPOT)             (LUNCH BAG  BLACK SKULL.)
# 15                (LUNCH BAG CARS BLUE)             (LUNCH BAG RED RETROSPOT)
# 16            (LUNCH BAG PINK POLKADOT)             (LUNCH BAG RED RETROSPOT)
# 17            (LUNCH BAG RED RETROSPOT)             (LUNCH BAG PINK POLKADOT)
# 18          (LUNCH BAG SPACEBOY DESIGN)             (LUNCH BAG RED RETROSPOT)
# 20              (LUNCH BAG SUKI DESIGN)             (LUNCH BAG RED RETROSPOT)
# 22     (PAPER CHAIN KIT 50'S CHRISTMAS)   (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 23  (PAPER CHAIN KIT VINTAGE CHRISTMAS)      (PAPER CHAIN KIT 50'S CHRISTMAS)
# 24   (RED HANGING HEART T-LIGHT HOLDER)  (WHITE HANGING HEART T-LIGHT HOLDER)
# 26  (WOODEN PICTURE FRAME WHITE FINISH)          (WOODEN FRAME ANTIQUE WHITE)
# 27         (WOODEN FRAME ANTIQUE WHITE)   (WOODEN PICTURE FRAME WHITE FINISH)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.035747            0.039734  0.024012    0.671736  16.906004
# 1             0.039734            0.035747  0.024012    0.604333  16.906004
# 2             0.028769            0.034252  0.020977    0.729134  21.287622
# 3             0.034252            0.028769  0.020977    0.612434  21.287622
# 4             0.025190            0.031307  0.020841    0.827338  26.426928
# 5             0.031307            0.025190  0.020841    0.665702  26.426928
# 6             0.035475            0.031307  0.024511    0.690932  22.069838
# 7             0.031307            0.035475  0.024511    0.782923  22.069838
# 8             0.039462            0.072490  0.024737    0.626866   8.647612
# 10            0.047662            0.042180  0.021022    0.441065  10.456690
# 11            0.042180            0.047662  0.021022    0.498389  10.456690
# 12            0.047662            0.058354  0.023423    0.491445   8.421717
# 13            0.058354            0.047662  0.023423    0.401398   8.421717
# 15            0.043766            0.058354  0.020750    0.474120   8.124828
# 16            0.042180            0.058354  0.023695    0.561762   9.626709
# 17            0.058354            0.042180  0.023695    0.406056   9.626709
# 18            0.044763            0.058354  0.021158    0.472672   8.100014
# 20            0.040730            0.058354  0.020388    0.500556   8.577854
# 22            0.044400            0.031578  0.020433    0.460204  14.573349
# 23            0.031578            0.044400  0.020433    0.647059  14.573349
# 24            0.030763            0.089299  0.020614    0.670103   7.504067
# 26            0.039688            0.036743  0.021203    0.534247  14.539939
# 27            0.036743            0.039688  0.021203    0.577065  14.539939
#
#     leverage  conviction  zhangs_metric
# 0   0.022592    2.925290       0.975728
# 1   0.022592    2.437032       0.979780
# 2   0.019991    3.565409       0.981255
# 3   0.019991    2.505974       0.986825
# 4   0.020052    5.610349       0.987023
# 5   0.020052    2.915989       0.993255
# 6   0.023400    3.134243       0.989802
# 7   0.023400    4.443246       0.985543
# 8   0.021877    2.485727       0.920693
# 10  0.019012    1.713651       0.949629
# 11  0.019012    1.898558       0.944194
# 12  0.020642    1.851610       0.925364
# 13  0.020642    1.590935       0.935872
# 15  0.018196    1.790609       0.917056
# 16  0.021234    2.148706       0.935585
# 17  0.021234    1.612643       0.951656
# 18  0.018546    1.785692       0.917618
# 20  0.018011    1.885388       0.920931
# 22  0.019031    1.794051       0.974656
# 23  0.019031    2.707533       0.961752
# 24  0.017867    2.760563       0.894249
# 26  0.019745    2.068169       0.969710
# 27  0.019745    2.270591       0.966745
